# %%
#import libraries 
import pandas as pd
import numpy as np

# %%
# The path to our CSV file
merged_data = "../Bakers_Island_Data/221315.csv"

# Read our Crowdfunding data into pandas
merged_df = pd.read_csv(merged_data, error_bad_lines=False)
merged_df.head()
len(merged_df)
# Out:
# C:\Users\katel\AppData\Local\Temp\ipykernel_26700\327485008.py:5: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   merged_df = pd.read_csv(merged_data, error_bad_lines=False)
# Skipping line 8643: expected 65 fields, saw 66
#
# Skipping line 17382: expected 65 fields, saw 66
#
# Skipping line 26216: expected 65 fields, saw 66
#
# Skipping line 35049: expected 65 fields, saw 66
#
# Skipping line 43689: expected 65 fields, saw 66
#
# Skipping line 52429: expected 65 fields, saw 66
#
# Skipping line 61264: expected 65 fields, saw 66
#
# Skipping line 70096: expected 65 fields, saw 66
#
# Skipping line 78832: expected 65 fields, saw 66
#
# Skipping line 87568: expected 65 fields, saw 66
#
# Skipping line 96404: expected 65 fields, saw 66
#
# Skipping line 105236: expected 65 fields, saw 66
#
# Skipping line 113876: expected 65 fields, saw 66
#
# Skipping line 122615: expected 65 fields, saw 66
#
# Skipping line 131451: expected 65 fields, saw 66
#
# Skipping line 140286: expected 65 fields, saw 66
#
# Skipping line 148926: expected 65 fields, saw 66
#
# Skipping line 157663: expected 65 fields, saw 66
#
# Skipping line 166498: expected 65 fields, saw 66
#
# C:\Users\katel\AppData\Local\Temp\ipykernel_26700\327485008.py:5: DtypeWarning: Columns (3,17,24,25,27,29,31,33,35,37,39,41,43,45,47,51,53,55,57,59,61,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged_df = pd.read_csv(merged_data, error_bad_lines=False)
# 175310

# %%
# Get a list of all of our columns for easy reference
merged_df.columns
# Out:
# Index(['DateTimeStamp', 'LKSPOMET_Station_Code', 'LKSPOMET_isSWMP',
#        'LKSPOMET_F_Record', 'LKSPOMET_ATemp', 'LKSPOMET_F_ATemp',
#        'LKSPOMET_RH', 'LKSPOMET_F_RH', 'LKSPOMET_BP', 'LKSPOMET_F_BP',
#        'LKSPOMET_WSpd', 'LKSPOMET_F_WSpd', 'LKSPOMET_MaxWSpd', 'LKSPOMET_Wdir',
#        'LKSPOMET_F_Wdir', 'LKSPOMET_SDWDir', 'LKSPOMET_F_SDWDir',
#        'LKSPOMET_TotPAR', 'LKSPOMET_F_TotPAR', 'LKSPOMET_TotPrcp',
#        'LKSPOMET_F_TotPrcp', 'LKSPOMET_TotSoRad', 'LKSPOMET_F_TotSoRad',
#        'LKSBAWQ_Station_Code', 'LKSBAWQ_isSWMP', 'LKSBAWQ_F_Record',
#        'LKSBAWQ_Temp', 'LKSBAWQ_F_Temp', 'LKSBAWQ_SpCond', 'LKSBAWQ_F_SpCond',
#        'LKSBAWQ_Sal', 'LKSBAWQ_F_Sal', 'LKSBAWQ_DO_pct', 'LKSBAWQ_F_DO_pct',
#        'LKSBAWQ_DO_mgl', 'LKSBAWQ_F_DO_mgl', 'LKSBAWQ_Depth',
#        'LKSBAWQ_F_Depth', 'LKSBAWQ_cDepth', 'LKSBAWQ_F_cDepth', 'LKSBAWQ_pH',
#        'LKSBAWQ_F_pH', 'LKSBAWQ_Turb', 'LKSBAWQ_F_Turb', 'LKSBAWQ_ChlFluor',
#        'LKSBAWQ_F_ChlFluor', 'LKSBANUT_Station_Code', 'LKSBANUT_isSWMP',
#        'LKSBANUT_DateTimeStamp', 'LKSBANUT_CollMethd', 'LKSBANUT_REP',
#        'LKSBANUT_F_Record', 'LKSBANUT_PO4F', 'LKSBANUT_F_PO4F',
#        'LKSBANUT_NH4F', 'LKSBANUT_F_NH4F', 'LKSBANUT_NO2F', 'LKSBANUT_F_NO2F',
#        'LKSBANUT_NO3F', 'LKSBANUT_F_NO3F', 'LKSBANUT_NO23F',
#        'LKSBANUT_F_NO23F', 'LKSBANUT_CHLA_N', 'LKSBANUT_F_CHLA_N',
#        'Unnamed: 64'],
#       dtype='object')

# %%
#Create data frame of prioritized data elements for analysis (water temp, water salinitiy, water depth, water pH, and total precipitation)
new_df = merged_df[['DateTimeStamp',
                    'LKSPOMET_ATemp', 'LKSPOMET_F_ATemp', 
                    'LKSBAWQ_Temp', 'LKSBAWQ_F_Temp',
                    'LKSPOMET_WSpd', 'LKSPOMET_F_WSpd',
                    'LKSBAWQ_Depth','LKSBAWQ_F_Depth', 
                    'LKSBAWQ_pH','LKSBAWQ_F_pH', 
                    'LKSBAWQ_ChlFluor', 'LKSBAWQ_F_ChlFluor',
                    'LKSPOMET_TotPrcp','LKSPOMET_F_TotPrcp',
                    'LKSBAWQ_Turb', 'LKSBAWQ_F_Turb'
                   ]]
new_df.head()
# Out:
#      DateTimeStamp  LKSPOMET_ATemp LKSPOMET_F_ATemp  LKSBAWQ_Temp  \
# 0  01/01/2018 0:00           -24.5             <0>            NaN
# 1  01/01/2018 0:15           -24.7             <0>            NaN
# 2  01/01/2018 0:30           -24.8             <0>            NaN
# 3  01/01/2018 0:45           -25.0             <0>            NaN
# 4  01/01/2018 1:00           -25.2             <0>            NaN
#
#   LKSBAWQ_F_Temp  LKSPOMET_WSpd LKSPOMET_F_WSpd  LKSBAWQ_Depth  \
# 0     <-2> [GIC]            0.9       <1> [GSM]            NaN
# 1     <-2> [GIC]            1.4       <1> [GSM]            NaN
# 2     <-2> [GIC]            1.7       <1> [GSM]            NaN
# 3     <-2> [GIC]            1.4       <1> [GSM]            NaN
# 4     <-2> [GIC]            1.6       <1> [GSM]            NaN
#
#   LKSBAWQ_F_Depth  LKSBAWQ_pH LKSBAWQ_F_pH  LKSBAWQ_ChlFluor  \
# 0      <-2> [GIC]         NaN   <-2> [GIC]               NaN
# 1      <-2> [GIC]         NaN   <-2> [GIC]               NaN
# 2      <-2> [GIC]         NaN   <-2> [GIC]               NaN
# 3      <-2> [GIC]         NaN   <-2> [GIC]               NaN
# 4      <-2> [GIC]         NaN   <-2> [GIC]               NaN
#
#   LKSBAWQ_F_ChlFluor  LKSPOMET_TotPrcp LKSPOMET_F_TotPrcp  LKSBAWQ_Turb  \
# 0              <-1>                0.0         <-3> (CSM)           NaN
# 1              <-1>                0.0         <-3> (CSM)           NaN
# 2              <-1>                0.0         <-3> (CSM)           NaN
# 3              <-1>                0.0         <-3> (CSM)           NaN
# 4              <-1>                0.0         <-3> (CSM)           NaN
#
#   LKSBAWQ_F_Turb
# 0     <-2> [GIC]
# 1     <-2> [GIC]
# 2     <-2> [GIC]
# 3     <-2> [GIC]
# 4     <-2> [GIC]

# %%
# Check air temperature column values 

#metTemp_Values = new_df['LKSPOMET_F_ATemp'].values.tolist()
#print(metTemp_Values)

# %%
#Exclude data that was flagged (0=Passed Initial QAQC Checks,  5=Corrected Data)
quality_codes = ['<0> ', '<0> [GMT]','<5> '];
filtered_mettemp_df = new_df[new_df['LKSPOMET_F_ATemp'].isin(quality_codes)]
#filtered_mettemp_df.head()
len(filtered_mettemp_df)
# Out:
# 159772

# %%
#Exclude data that was flagged (0=Passed Initial QAQC Checks,  5=Corrected Data)
quality_codes = ['<0> ', '<0> [GMT]','<5> '];
wqtemp_df = filtered_mettemp_df[filtered_mettemp_df['LKSBAWQ_F_Temp'].isin(quality_codes)]
#wqtemp_df.head()
len(wqtemp_df)
# Out:
# 90441

# %%
#Exclude data that was flagged (0=Passed Initial QAQC Checks,  5=Corrected Data) LKSBAWQ_F_Depth
quality_codes = ['<0> ', '<0> [GMT]','<5> '];
wsp_df = wqtemp_df[wqtemp_df['LKSPOMET_F_WSpd'].isin(quality_codes)]
#depth_df.head()
len(wsp_df)
# Out:
# 90437

# %%
#Exclude data that was flagged (0=Passed Initial QAQC Checks,  5=Corrected Data) LKSBAWQ_F_Depth
quality_codes = ['<0> ', '<0> [GMT]','<5> '];
depth_df = wsp_df[wsp_df['LKSBAWQ_F_Depth'].isin(quality_codes)]
#depth_df.head()
len(depth_df)
# Out:
# 84519

# %%
#Exclude data that was flagged (0=Passed Initial QAQC Checks,  5=Corrected Data) LKSBAWQ_F_pH
quality_codes = ['<0> ', '<0> [GMT]','<5> '];
pH_df = depth_df[depth_df['LKSBAWQ_F_pH'].isin(quality_codes)]
#pH_df.head()
len(pH_df)
# Out:
# 80664

# %%
#Exclude data that was flagged (0=Passed Initial QAQC Checks,  5=Corrected Data) LKSPOMET_F_TotPrcp
quality_codes = ['<0> ', '<0> [GMT]','<5> '];
chlf_df = pH_df[pH_df['LKSBAWQ_F_ChlFluor'].isin(quality_codes)]
#precip_df.head()
len(chlf_df)
# Out:
# 30584

# %%
#Exclude data that was flagged (0=Passed Initial QAQC Checks,  5=Corrected Data) LKSBAWQ_F_Turb
quality_codes = ['<0> ', '<0> [GMT]','<5> '];
turbidity_df = chlf_df[chlf_df['LKSBAWQ_F_Turb'].isin(quality_codes)]
#turbidity_df.head()
len(turbidity_df)
# Out:
# 30572

# %%
#Check dataframe
turbidity_df.head()
# Out:
#            DateTimeStamp  LKSPOMET_ATemp LKSPOMET_F_ATemp  LKSBAWQ_Temp  \
# 121310  06/17/2021 13:30            27.5             <0>           22.0
# 121311  06/17/2021 13:45            27.5             <0>           21.9
# 121312  06/17/2021 14:00            27.4             <0>           22.1
# 121313  06/17/2021 14:15            27.5             <0>           22.1
# 121314  06/17/2021 14:30            28.1             <0>           22.0
#
#        LKSBAWQ_F_Temp  LKSPOMET_WSpd LKSPOMET_F_WSpd  LKSBAWQ_Depth  \
# 121310           <0>             3.5            <0>            1.22
# 121311           <0>             3.5            <0>            1.21
# 121312           <0>             2.4            <0>            1.23
# 121313           <0>             1.9            <0>            1.24
# 121314           <0>             1.1            <0>            1.28
#
#        LKSBAWQ_F_Depth  LKSBAWQ_pH LKSBAWQ_F_pH  LKSBAWQ_ChlFluor  \
# 121310            <0>          7.9         <0>               13.8
# 121311            <0>          7.9         <0>               14.2
# 121312            <0>          7.9         <0>               13.7
# 121313            <0>          7.9         <0>               13.0
# 121314            <0>          7.9         <0>               13.4
#
#        LKSBAWQ_F_ChlFluor  LKSPOMET_TotPrcp LKSPOMET_F_TotPrcp  LKSBAWQ_Turb  \
# 121310               <0>                0.0               <0>           11.0
# 121311               <0>                0.0               <0>           11.0
# 121312               <0>                0.0               <0>           12.0
# 121313               <0>                0.0               <0>           10.0
# 121314               <0>                0.0               <0>           11.0
#
#        LKSBAWQ_F_Turb
# 121310           <0>
# 121311           <0>
# 121312           <0>
# 121313           <0>
# 121314           <0>

# %%
#Split date and time into separate columns
turbidity_df[['Date','Time']] = turbidity_df.DateTimeStamp.str.split(" ", expand = True)
turbidity_df.head()
# Out:
# C:\Users\katel\AppData\Local\Temp\ipykernel_26700\3236543836.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   turbidity_df[['Date','Time']] = turbidity_df.DateTimeStamp.str.split(" ", expand = True)
# C:\Users\katel\AppData\Local\Temp\ipykernel_26700\3236543836.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   turbidity_df[['Date','Time']] = turbidity_df.DateTimeStamp.str.split(" ", expand = True)
#            DateTimeStamp  LKSPOMET_ATemp LKSPOMET_F_ATemp  LKSBAWQ_Temp  \
# 121310  06/17/2021 13:30            27.5             <0>           22.0
# 121311  06/17/2021 13:45            27.5             <0>           21.9
# 121312  06/17/2021 14:00            27.4             <0>           22.1
# 121313  06/17/2021 14:15            27.5             <0>           22.1
# 121314  06/17/2021 14:30            28.1             <0>           22.0
#
#        LKSBAWQ_F_Temp  LKSPOMET_WSpd LKSPOMET_F_WSpd  LKSBAWQ_Depth  \
# 121310           <0>             3.5            <0>            1.22
# 121311           <0>             3.5            <0>            1.21
# 121312           <0>             2.4            <0>            1.23
# 121313           <0>             1.9            <0>            1.24
# 121314           <0>             1.1            <0>            1.28
#
#        LKSBAWQ_F_Depth  LKSBAWQ_pH LKSBAWQ_F_pH  LKSBAWQ_ChlFluor  \
# 121310            <0>          7.9         <0>               13.8
# 121311            <0>          7.9         <0>               14.2
# 121312            <0>          7.9         <0>               13.7
# 121313            <0>          7.9         <0>               13.0
# 121314            <0>          7.9         <0>               13.4
#
#        LKSBAWQ_F_ChlFluor  LKSPOMET_TotPrcp LKSPOMET_F_TotPrcp  LKSBAWQ_Turb  \
# 121310               <0>                0.0               <0>           11.0
# 121311               <0>                0.0               <0>           11.0
# 121312               <0>                0.0               <0>           12.0
# 121313               <0>                0.0               <0>           10.0
# 121314               <0>                0.0               <0>           11.0
#
#        LKSBAWQ_F_Turb        Date   Time
# 121310           <0>   06/17/2021  13:30
# 121311           <0>   06/17/2021  13:45
# 121312           <0>   06/17/2021  14:00
# 121313           <0>   06/17/2021  14:15
# 121314           <0>   06/17/2021  14:30

# %%
#Define new data frame dropping the combined DTS
new_turbidity_df = turbidity_df[['DateTimeStamp',
                    'LKSPOMET_ATemp', 'LKSPOMET_F_ATemp', 
                    'LKSBAWQ_Temp', 'LKSBAWQ_F_Temp',
                    'LKSPOMET_WSpd', 'LKSPOMET_F_WSpd',
                    'LKSBAWQ_Depth','LKSBAWQ_F_Depth', 
                    'LKSBAWQ_pH','LKSBAWQ_F_pH', 
                    'LKSBAWQ_ChlFluor', 'LKSBAWQ_F_ChlFluor',
                    'LKSPOMET_TotPrcp','LKSPOMET_F_TotPrcp',
                    'LKSBAWQ_Turb', 'LKSBAWQ_F_Turb',
                    'Date','Time'
                   ]]
new_turbidity_df.head()
# Out:
#            DateTimeStamp  LKSPOMET_ATemp LKSPOMET_F_ATemp  LKSBAWQ_Temp  \
# 121310  06/17/2021 13:30            27.5             <0>           22.0
# 121311  06/17/2021 13:45            27.5             <0>           21.9
# 121312  06/17/2021 14:00            27.4             <0>           22.1
# 121313  06/17/2021 14:15            27.5             <0>           22.1
# 121314  06/17/2021 14:30            28.1             <0>           22.0
#
#        LKSBAWQ_F_Temp  LKSPOMET_WSpd LKSPOMET_F_WSpd  LKSBAWQ_Depth  \
# 121310           <0>             3.5            <0>            1.22
# 121311           <0>             3.5            <0>            1.21
# 121312           <0>             2.4            <0>            1.23
# 121313           <0>             1.9            <0>            1.24
# 121314           <0>             1.1            <0>            1.28
#
#        LKSBAWQ_F_Depth  LKSBAWQ_pH LKSBAWQ_F_pH  LKSBAWQ_ChlFluor  \
# 121310            <0>          7.9         <0>               13.8
# 121311            <0>          7.9         <0>               14.2
# 121312            <0>          7.9         <0>               13.7
# 121313            <0>          7.9         <0>               13.0
# 121314            <0>          7.9         <0>               13.4
#
#        LKSBAWQ_F_ChlFluor  LKSPOMET_TotPrcp LKSPOMET_F_TotPrcp  LKSBAWQ_Turb  \
# 121310               <0>                0.0               <0>           11.0
# 121311               <0>                0.0               <0>           11.0
# 121312               <0>                0.0               <0>           12.0
# 121313               <0>                0.0               <0>           10.0
# 121314               <0>                0.0               <0>           11.0
#
#        LKSBAWQ_F_Turb        Date   Time
# 121310           <0>   06/17/2021  13:30
# 121311           <0>   06/17/2021  13:45
# 121312           <0>   06/17/2021  14:00
# 121313           <0>   06/17/2021  14:15
# 121314           <0>   06/17/2021  14:30

# %%
#Split time into separate columns
#turbidity_df[['Hour','Minute']] = turbidity_df.Time.str.split(":", expand = True)
#turbidity_df.head()

# %%
#for clean.csv
#average_measurement_df = new_turbidity_df

#for cleaned_groupby_date.csv
average_measurement_df = new_turbidity_df.groupby('Date').mean()
average_measurement_df.head()
# Out:
# C:\Users\katel\AppData\Local\Temp\ipykernel_26700\3023223079.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   average_measurement_df = new_turbidity_df.groupby('Date').mean()
#             LKSPOMET_ATemp  LKSBAWQ_Temp  LKSPOMET_WSpd  LKSBAWQ_Depth  \
# Date
# 04/13/2022        1.044828      0.624138       1.691379       0.829310
# 04/14/2022       -0.623958      0.451042       2.719792       0.703958
# 04/15/2022       -4.215625      0.441667       4.210417       0.789479
# 04/16/2022       -1.865625      0.636458       3.047917       0.964688
# 04/17/2022       -1.354167      1.016667       1.612500       1.077187
#
#             LKSBAWQ_pH  LKSBAWQ_ChlFluor  LKSPOMET_TotPrcp  LKSBAWQ_Turb
# Date
# 04/13/2022    7.574138          9.994828               0.0     15.189655
# 04/14/2022    7.582292         10.211458               0.0     15.395833
# 04/15/2022    7.600000          9.373958               0.0     13.875000
# 04/16/2022    7.600000          9.379167               0.0     12.906250
# 04/17/2022    7.559375          9.539583               0.0     12.364583

# %%
#Add ranges for turbidity 
conditions = [
    average_measurement_df['LKSBAWQ_Turb'] < 6,
    average_measurement_df['LKSBAWQ_Turb'] < 11,
    average_measurement_df['LKSBAWQ_Turb'] < 16,
    average_measurement_df['LKSBAWQ_Turb'] < 21,
    average_measurement_df['LKSBAWQ_Turb'] < 26,
    average_measurement_df['LKSBAWQ_Turb'] < 30,
    average_measurement_df['LKSBAWQ_Turb'] < 36,
    average_measurement_df['LKSBAWQ_Turb'] < 41,
    average_measurement_df['LKSBAWQ_Turb'] < 46,
    average_measurement_df['LKSBAWQ_Turb'] < 50,
]

outputs = ["</=5","</=10","</=15","</=20",
          "</=25","</=30", "</=35","</=40","</=45", "</=50"]



average_measurement_df['Turbidity_Range'] = np.select(conditions, outputs)
average_measurement_df.head()
# Out:
#             LKSPOMET_ATemp  LKSBAWQ_Temp  LKSPOMET_WSpd  LKSBAWQ_Depth  \
# Date
# 04/13/2022        1.044828      0.624138       1.691379       0.829310
# 04/14/2022       -0.623958      0.451042       2.719792       0.703958
# 04/15/2022       -4.215625      0.441667       4.210417       0.789479
# 04/16/2022       -1.865625      0.636458       3.047917       0.964688
# 04/17/2022       -1.354167      1.016667       1.612500       1.077187
#
#             LKSBAWQ_pH  LKSBAWQ_ChlFluor  LKSPOMET_TotPrcp  LKSBAWQ_Turb  \
# Date
# 04/13/2022    7.574138          9.994828               0.0     15.189655
# 04/14/2022    7.582292         10.211458               0.0     15.395833
# 04/15/2022    7.600000          9.373958               0.0     13.875000
# 04/16/2022    7.600000          9.379167               0.0     12.906250
# 04/17/2022    7.559375          9.539583               0.0     12.364583
#
#            Turbidity_Range
# Date
# 04/13/2022           </=15
# 04/14/2022           </=15
# 04/15/2022           </=15
# 04/16/2022           </=15
# 04/17/2022           </=15

# %%
#Export cleaned filtered data to new csv
average_measurement_df.to_csv('cleaned_groupby_date.csv')
