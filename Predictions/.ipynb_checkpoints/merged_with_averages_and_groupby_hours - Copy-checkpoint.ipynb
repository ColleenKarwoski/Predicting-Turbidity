# %%
#import libraries 
import pandas as pd
import numpy as np

# %%
# The path to our CSV file
merged_data = "6_summer_turbidity_with_hours.csv"

# Read our Crowdfunding data into pandas
merged_df = pd.read_csv(merged_data, error_bad_lines=False)
merged_df.head()
len(merged_df)
# Out:
# C:\Users\katel\AppData\Local\Temp\ipykernel_39884\1419685120.py:5: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   merged_df = pd.read_csv(merged_data, error_bad_lines=False)
# 13820

# %%
# Get a list of all of our columns for easy reference
merged_df.columns
# Out:
# Index(['Unnamed: 0', '_c0', 'Date', 'Hour', 'Minute', 'LKSPOMET_ATemp',
#        'LKSPOMET_F_ATemp', 'LKSBAWQ_ChlFluor', 'LKSBAWQ_F_ChlFluor',
#        'LKSBAWQ_Temp', 'LKSBAWQ_F_Temp', 'LKSPOMET_WSpd', 'LKSPOMET_F_WSpd',
#        'LKSBAWQ_Depth', 'LKSBAWQ_F_Depth', 'LKSBAWQ_pH', 'LKSBAWQ_F_pH',
#        'LKSBAWQ_Turb', 'LKSBAWQ_F_Turb', 'Turbidity_Range', 'Month', 'Day',
#        'Year'],
#       dtype='object')

# %%
#Create data frame of prioritized data elements for analysis (water temp, water salinitiy, water depth, water pH, and total precipitation)
new_df = merged_df[['Date', 'Hour', 'Minute', 'LKSPOMET_ATemp',
       'LKSPOMET_F_ATemp', 'LKSBAWQ_ChlFluor', 'LKSBAWQ_F_ChlFluor',
       'LKSBAWQ_Temp', 'LKSBAWQ_F_Temp', 'LKSPOMET_WSpd', 'LKSPOMET_F_WSpd',
       'LKSBAWQ_Depth', 'LKSBAWQ_F_Depth', 'LKSBAWQ_pH', 'LKSBAWQ_F_pH',
       'LKSBAWQ_Turb', 'LKSBAWQ_F_Turb', 'Turbidity_Range', 'Month', 'Day',
       'Year'
                   ]]
new_df.head()
# Out:
#          Date  Hour  Minute  LKSPOMET_ATemp LKSPOMET_F_ATemp  \
# 0  06/17/2021    13      30            27.5             <0>
# 1  06/17/2021    13      45            27.5             <0>
# 2  06/17/2021    14       0            27.4             <0>
# 3  06/17/2021    14      15            27.5             <0>
# 4  06/17/2021    14      30            28.1             <0>
#
#    LKSBAWQ_ChlFluor LKSBAWQ_F_ChlFluor  LKSBAWQ_Temp LKSBAWQ_F_Temp  \
# 0              13.8               <0>           22.0           <0>
# 1              14.2               <0>           21.9           <0>
# 2              13.7               <0>           22.1           <0>
# 3              13.0               <0>           22.1           <0>
# 4              13.4               <0>           22.0           <0>
#
#    LKSPOMET_WSpd  ... LKSBAWQ_Depth  LKSBAWQ_F_Depth LKSBAWQ_pH  LKSBAWQ_F_pH  \
# 0            3.5  ...          1.22             <0>         7.9          <0>
# 1            3.5  ...          1.21             <0>         7.9          <0>
# 2            2.4  ...          1.23             <0>         7.9          <0>
# 3            1.9  ...          1.24             <0>         7.9          <0>
# 4            1.1  ...          1.28             <0>         7.9          <0>
#
#   LKSBAWQ_Turb  LKSBAWQ_F_Turb Turbidity_Range Month  Day  Year
# 0         11.0            <0>            </=15     6   17  2021
# 1         11.0            <0>            </=15     6   17  2021
# 2         12.0            <0>            </=15     6   17  2021
# 3         10.0            <0>            </=10     6   17  2021
# 4         11.0            <0>            </=15     6   17  2021
#
# [5 rows x 21 columns]

# %%
# Check air temperature column values 

#metTemp_Values = new_df['LKSPOMET_F_ATemp'].values.tolist()
#print(metTemp_Values)

# %%
#Exclude data that was flagged (0=Passed Initial QAQC Checks,  5=Corrected Data) LKSBAWQ_F_Depth
quality_codes = ['<0> ', '<0> [GMT]','<5> '];
wsp_df = wqtemp_df[wqtemp_df['LKSPOMET_F_WSpd'].isin(quality_codes)]
#depth_df.head()
len(wsp_df)
# Out:
# 90437

# %%
#Exclude data that was flagged (0=Passed Initial QAQC Checks,  5=Corrected Data) LKSBAWQ_F_Depth
quality_codes = ['<0> ', '<0> [GMT]','<5> '];
depth_df = wsp_df[wsp_df['LKSBAWQ_F_Depth'].isin(quality_codes)]
#depth_df.head()
len(depth_df)
# Out:
# 84519

# %%
#Exclude data that was flagged (0=Passed Initial QAQC Checks,  5=Corrected Data) LKSBAWQ_F_pH
quality_codes = ['<0> ', '<0> [GMT]','<5> '];
pH_df = depth_df[depth_df['LKSBAWQ_F_pH'].isin(quality_codes)]
#pH_df.head()
len(pH_df)
# Out:
# 80664

# %%
#Exclude data that was flagged (0=Passed Initial QAQC Checks,  5=Corrected Data) LKSPOMET_F_TotPrcp
quality_codes = ['<0> ', '<0> [GMT]','<5> '];
chlf_df = pH_df[pH_df['LKSBAWQ_F_ChlFluor'].isin(quality_codes)]
#precip_df.head()
len(chlf_df)
# Out:
# 30584

# %%
#Exclude data that was flagged (0=Passed Initial QAQC Checks,  5=Corrected Data) LKSBAWQ_F_Turb
quality_codes = ['<0> ', '<0> [GMT]','<5> '];
turbidity_df = chlf_df[chlf_df['LKSBAWQ_F_Turb'].isin(quality_codes)]
#turbidity_df.head()
len(turbidity_df)
# Out:
# 30572

# %%
#Check dataframe
turbidity_df.head()
# Out:
#            DateTimeStamp  LKSPOMET_ATemp LKSPOMET_F_ATemp  LKSBAWQ_Temp  \
# 121310  06/17/2021 13:30            27.5             <0>           22.0
# 121311  06/17/2021 13:45            27.5             <0>           21.9
# 121312  06/17/2021 14:00            27.4             <0>           22.1
# 121313  06/17/2021 14:15            27.5             <0>           22.1
# 121314  06/17/2021 14:30            28.1             <0>           22.0
#
#        LKSBAWQ_F_Temp  LKSPOMET_WSpd LKSPOMET_F_WSpd  LKSBAWQ_Depth  \
# 121310           <0>             3.5            <0>            1.22
# 121311           <0>             3.5            <0>            1.21
# 121312           <0>             2.4            <0>            1.23
# 121313           <0>             1.9            <0>            1.24
# 121314           <0>             1.1            <0>            1.28
#
#        LKSBAWQ_F_Depth  LKSBAWQ_pH LKSBAWQ_F_pH  LKSBAWQ_ChlFluor  \
# 121310            <0>          7.9         <0>               13.8
# 121311            <0>          7.9         <0>               14.2
# 121312            <0>          7.9         <0>               13.7
# 121313            <0>          7.9         <0>               13.0
# 121314            <0>          7.9         <0>               13.4
#
#        LKSBAWQ_F_ChlFluor  LKSBAWQ_Turb LKSBAWQ_F_Turb
# 121310               <0>           11.0           <0>
# 121311               <0>           11.0           <0>
# 121312               <0>           12.0           <0>
# 121313               <0>           10.0           <0>
# 121314               <0>           11.0           <0>

# %%
#Split date and time into separate columns
turbidity_df[['Date','Time']] = turbidity_df.DateTimeStamp.str.split(" ", expand = True)
turbidity_df.head()
# Out:
# C:\Users\katel\AppData\Local\Temp\ipykernel_24664\3236543836.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   turbidity_df[['Date','Time']] = turbidity_df.DateTimeStamp.str.split(" ", expand = True)
# C:\Users\katel\AppData\Local\Temp\ipykernel_24664\3236543836.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   turbidity_df[['Date','Time']] = turbidity_df.DateTimeStamp.str.split(" ", expand = True)
#            DateTimeStamp  LKSPOMET_ATemp LKSPOMET_F_ATemp  LKSBAWQ_Temp  \
# 121310  06/17/2021 13:30            27.5             <0>           22.0
# 121311  06/17/2021 13:45            27.5             <0>           21.9
# 121312  06/17/2021 14:00            27.4             <0>           22.1
# 121313  06/17/2021 14:15            27.5             <0>           22.1
# 121314  06/17/2021 14:30            28.1             <0>           22.0
#
#        LKSBAWQ_F_Temp  LKSPOMET_WSpd LKSPOMET_F_WSpd  LKSBAWQ_Depth  \
# 121310           <0>             3.5            <0>            1.22
# 121311           <0>             3.5            <0>            1.21
# 121312           <0>             2.4            <0>            1.23
# 121313           <0>             1.9            <0>            1.24
# 121314           <0>             1.1            <0>            1.28
#
#        LKSBAWQ_F_Depth  LKSBAWQ_pH LKSBAWQ_F_pH  LKSBAWQ_ChlFluor  \
# 121310            <0>          7.9         <0>               13.8
# 121311            <0>          7.9         <0>               14.2
# 121312            <0>          7.9         <0>               13.7
# 121313            <0>          7.9         <0>               13.0
# 121314            <0>          7.9         <0>               13.4
#
#        LKSBAWQ_F_ChlFluor  LKSBAWQ_Turb LKSBAWQ_F_Turb        Date   Time
# 121310               <0>           11.0           <0>   06/17/2021  13:30
# 121311               <0>           11.0           <0>   06/17/2021  13:45
# 121312               <0>           12.0           <0>   06/17/2021  14:00
# 121313               <0>           10.0           <0>   06/17/2021  14:15
# 121314               <0>           11.0           <0>   06/17/2021  14:30

# %%
#Define new data frame dropping the combined DTS
new_turbidity_df = turbidity_df[['Date', 'Time',
                    'LKSPOMET_ATemp', 'LKSPOMET_F_ATemp', 
                   'LKSBAWQ_ChlFluor', 'LKSBAWQ_F_ChlFluor',
                    'LKSBAWQ_Temp', 'LKSBAWQ_F_Temp',
                    'LKSPOMET_WSpd', 'LKSPOMET_F_WSpd',
                   'LKSBAWQ_Depth','LKSBAWQ_F_Depth', 
                    'LKSBAWQ_pH','LKSBAWQ_F_pH', 
                    'LKSBAWQ_Turb', 'LKSBAWQ_F_Turb'
                   ]]
new_turbidity_df.head()
# Out:
#               Date   Time  LKSPOMET_ATemp LKSPOMET_F_ATemp  LKSBAWQ_ChlFluor  \
# 121310  06/17/2021  13:30            27.5             <0>               13.8
# 121311  06/17/2021  13:45            27.5             <0>               14.2
# 121312  06/17/2021  14:00            27.4             <0>               13.7
# 121313  06/17/2021  14:15            27.5             <0>               13.0
# 121314  06/17/2021  14:30            28.1             <0>               13.4
#
#        LKSBAWQ_F_ChlFluor  LKSBAWQ_Temp LKSBAWQ_F_Temp  LKSPOMET_WSpd  \
# 121310               <0>           22.0           <0>             3.5
# 121311               <0>           21.9           <0>             3.5
# 121312               <0>           22.1           <0>             2.4
# 121313               <0>           22.1           <0>             1.9
# 121314               <0>           22.0           <0>             1.1
#
#        LKSPOMET_F_WSpd  LKSBAWQ_Depth LKSBAWQ_F_Depth  LKSBAWQ_pH  \
# 121310            <0>            1.22            <0>          7.9
# 121311            <0>            1.21            <0>          7.9
# 121312            <0>            1.23            <0>          7.9
# 121313            <0>            1.24            <0>          7.9
# 121314            <0>            1.28            <0>          7.9
#
#        LKSBAWQ_F_pH  LKSBAWQ_Turb LKSBAWQ_F_Turb
# 121310         <0>           11.0           <0>
# 121311         <0>           11.0           <0>
# 121312         <0>           12.0           <0>
# 121313         <0>           10.0           <0>
# 121314         <0>           11.0           <0>

# %%
#Split time into separate columns
turbidity_df[['Hour','Minute']] = turbidity_df.Time.str.split(":", expand = True)
turbidity_df.head()
# Out:
# C:\Users\katel\AppData\Local\Temp\ipykernel_24664\1408831108.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   turbidity_df[['Hour','Minute']] = turbidity_df.Time.str.split(":", expand = True)
# C:\Users\katel\AppData\Local\Temp\ipykernel_24664\1408831108.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   turbidity_df[['Hour','Minute']] = turbidity_df.Time.str.split(":", expand = True)
#            DateTimeStamp  LKSPOMET_ATemp LKSPOMET_F_ATemp  LKSBAWQ_Temp  \
# 121310  06/17/2021 13:30            27.5             <0>           22.0
# 121311  06/17/2021 13:45            27.5             <0>           21.9
# 121312  06/17/2021 14:00            27.4             <0>           22.1
# 121313  06/17/2021 14:15            27.5             <0>           22.1
# 121314  06/17/2021 14:30            28.1             <0>           22.0
#
#        LKSBAWQ_F_Temp  LKSPOMET_WSpd LKSPOMET_F_WSpd  LKSBAWQ_Depth  \
# 121310           <0>             3.5            <0>            1.22
# 121311           <0>             3.5            <0>            1.21
# 121312           <0>             2.4            <0>            1.23
# 121313           <0>             1.9            <0>            1.24
# 121314           <0>             1.1            <0>            1.28
#
#        LKSBAWQ_F_Depth  LKSBAWQ_pH  ... LKSBAWQ_ChlFluor  LKSBAWQ_F_ChlFluor  \
# 121310            <0>          7.9  ...             13.8                <0>
# 121311            <0>          7.9  ...             14.2                <0>
# 121312            <0>          7.9  ...             13.7                <0>
# 121313            <0>          7.9  ...             13.0                <0>
# 121314            <0>          7.9  ...             13.4                <0>
#
#        LKSBAWQ_Turb  LKSBAWQ_F_Turb        Date   Time Hours Minutes Hour  \
# 121310         11.0            <0>   06/17/2021  13:30    13      30   13
# 121311         11.0            <0>   06/17/2021  13:45    13      45   13
# 121312         12.0            <0>   06/17/2021  14:00    14      00   14
# 121313         10.0            <0>   06/17/2021  14:15    14      15   14
# 121314         11.0            <0>   06/17/2021  14:30    14      30   14
#
#        Minute
# 121310     30
# 121311     45
# 121312     00
# 121313     15
# 121314     30
#
# [5 rows x 21 columns]

# %%
#Define new data frame dropping the combined Time
new_turbidity_df = turbidity_df[['Date', 'Hour',
                    'LKSPOMET_ATemp', 'LKSPOMET_F_ATemp', 
                   'LKSBAWQ_ChlFluor', 'LKSBAWQ_F_ChlFluor',
                    'LKSBAWQ_Temp', 'LKSBAWQ_F_Temp',
                    'LKSPOMET_WSpd', 'LKSPOMET_F_WSpd',
                   'LKSBAWQ_Depth','LKSBAWQ_F_Depth', 
                    'LKSBAWQ_pH','LKSBAWQ_F_pH', 
                    'LKSBAWQ_Turb', 'LKSBAWQ_F_Turb'
                   ]]
new_turbidity_df.head()
# Out:
#               Date Hour Minute  LKSPOMET_ATemp LKSPOMET_F_ATemp  \
# 121310  06/17/2021   13     30            27.5             <0>
# 121311  06/17/2021   13     45            27.5             <0>
# 121312  06/17/2021   14     00            27.4             <0>
# 121313  06/17/2021   14     15            27.5             <0>
# 121314  06/17/2021   14     30            28.1             <0>
#
#         LKSBAWQ_ChlFluor LKSBAWQ_F_ChlFluor  LKSBAWQ_Temp LKSBAWQ_F_Temp  \
# 121310              13.8               <0>           22.0           <0>
# 121311              14.2               <0>           21.9           <0>
# 121312              13.7               <0>           22.1           <0>
# 121313              13.0               <0>           22.1           <0>
# 121314              13.4               <0>           22.0           <0>
#
#         LKSPOMET_WSpd LKSPOMET_F_WSpd  LKSBAWQ_Depth LKSBAWQ_F_Depth  \
# 121310            3.5            <0>            1.22            <0>
# 121311            3.5            <0>            1.21            <0>
# 121312            2.4            <0>            1.23            <0>
# 121313            1.9            <0>            1.24            <0>
# 121314            1.1            <0>            1.28            <0>
#
#         LKSBAWQ_pH LKSBAWQ_F_pH  LKSBAWQ_Turb LKSBAWQ_F_Turb
# 121310         7.9         <0>           11.0           <0>
# 121311         7.9         <0>           11.0           <0>
# 121312         7.9         <0>           12.0           <0>
# 121313         7.9         <0>           10.0           <0>
# 121314         7.9         <0>           11.0           <0>

# %%
average_measurement_df = new_turbidity_df
#average_measurement_df = new_turbidity_df.groupby('Date').mean()
#average_measurement_df.head()

# %%
#Add ranges for turbidity 
conditions = [
    average_measurement_df['LKSBAWQ_Turb'] < 6,
    average_measurement_df['LKSBAWQ_Turb'] < 11,
    average_measurement_df['LKSBAWQ_Turb'] < 16,
    average_measurement_df['LKSBAWQ_Turb'] < 21,
    average_measurement_df['LKSBAWQ_Turb'] < 26,
    average_measurement_df['LKSBAWQ_Turb'] < 30,
    average_measurement_df['LKSBAWQ_Turb'] < 36,
    average_measurement_df['LKSBAWQ_Turb'] < 41,
    average_measurement_df['LKSBAWQ_Turb'] < 46,
    average_measurement_df['LKSBAWQ_Turb'] < 50,
]

outputs = ["</=5","</=10","</=15","</=20",
          "</=25","</=30", "</=35","</=40","</=45", "</=50"]



average_measurement_df['Turbidity_Range'] = np.select(conditions, outputs)
average_measurement_df.head()
# Out:
# C:\Users\katel\AppData\Local\Temp\ipykernel_24664\3311718761.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   average_measurement_df['Turbidity_Range'] = np.select(conditions, outputs)
#               Date Hour Minute  LKSPOMET_ATemp LKSPOMET_F_ATemp  \
# 121310  06/17/2021   13     30            27.5             <0>
# 121311  06/17/2021   13     45            27.5             <0>
# 121312  06/17/2021   14     00            27.4             <0>
# 121313  06/17/2021   14     15            27.5             <0>
# 121314  06/17/2021   14     30            28.1             <0>
#
#         LKSBAWQ_ChlFluor LKSBAWQ_F_ChlFluor  LKSBAWQ_Temp LKSBAWQ_F_Temp  \
# 121310              13.8               <0>           22.0           <0>
# 121311              14.2               <0>           21.9           <0>
# 121312              13.7               <0>           22.1           <0>
# 121313              13.0               <0>           22.1           <0>
# 121314              13.4               <0>           22.0           <0>
#
#         LKSPOMET_WSpd LKSPOMET_F_WSpd  LKSBAWQ_Depth LKSBAWQ_F_Depth  \
# 121310            3.5            <0>            1.22            <0>
# 121311            3.5            <0>            1.21            <0>
# 121312            2.4            <0>            1.23            <0>
# 121313            1.9            <0>            1.24            <0>
# 121314            1.1            <0>            1.28            <0>
#
#         LKSBAWQ_pH LKSBAWQ_F_pH  LKSBAWQ_Turb LKSBAWQ_F_Turb Turbidity_Range
# 121310         7.9         <0>           11.0           <0>            </=15
# 121311         7.9         <0>           11.0           <0>            </=15
# 121312         7.9         <0>           12.0           <0>            </=15
# 121313         7.9         <0>           10.0           <0>            </=10
# 121314         7.9         <0>           11.0           <0>            </=15

# %%
#Export cleaned filtered data to new csv
average_measurement_df.to_csv('6_turbidity_with_hours.csv')
