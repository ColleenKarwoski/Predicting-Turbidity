# %%
import pandas as pd

# %%
# The path to our CSV file
merged_data = "Bakers_Island_Data/221315.csv"

# Read our Crowdfunding data into pandas
merged_df = pd.read_csv(merged_data, error_bad_lines=False)
merged_df.head(50)
# Out:
# C:\Users\katel\AppData\Local\Temp\ipykernel_31388\875936951.py:5: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   merged_df = pd.read_csv(merged_data, error_bad_lines=False)
# Skipping line 8643: expected 65 fields, saw 66
#
# Skipping line 17382: expected 65 fields, saw 66
#
# Skipping line 26216: expected 65 fields, saw 66
#
# Skipping line 35049: expected 65 fields, saw 66
#
# Skipping line 43689: expected 65 fields, saw 66
#
# Skipping line 52429: expected 65 fields, saw 66
#
# Skipping line 61264: expected 65 fields, saw 66
#
# Skipping line 70096: expected 65 fields, saw 66
#
# Skipping line 78832: expected 65 fields, saw 66
#
# Skipping line 87568: expected 65 fields, saw 66
#
# Skipping line 96404: expected 65 fields, saw 66
#
# Skipping line 105236: expected 65 fields, saw 66
#
# Skipping line 113876: expected 65 fields, saw 66
#
# ...

# %%
# Get a list of all of our columns for easy reference
merged_df.columns
# Out:
# Index(['DateTimeStamp', 'LKSPOMET_Station_Code', 'LKSPOMET_isSWMP',
#        'LKSPOMET_F_Record', 'LKSPOMET_ATemp', 'LKSPOMET_F_ATemp',
#        'LKSPOMET_RH', 'LKSPOMET_F_RH', 'LKSPOMET_BP', 'LKSPOMET_F_BP',
#        'LKSPOMET_WSpd', 'LKSPOMET_F_WSpd', 'LKSPOMET_MaxWSpd', 'LKSPOMET_Wdir',
#        'LKSPOMET_F_Wdir', 'LKSPOMET_SDWDir', 'LKSPOMET_F_SDWDir',
#        'LKSPOMET_TotPAR', 'LKSPOMET_F_TotPAR', 'LKSPOMET_TotPrcp',
#        'LKSPOMET_F_TotPrcp', 'LKSPOMET_TotSoRad', 'LKSPOMET_F_TotSoRad',
#        'LKSBAWQ_Station_Code', 'LKSBAWQ_isSWMP', 'LKSBAWQ_F_Record',
#        'LKSBAWQ_Temp', 'LKSBAWQ_F_Temp', 'LKSBAWQ_SpCond', 'LKSBAWQ_F_SpCond',
#        'LKSBAWQ_Sal', 'LKSBAWQ_F_Sal', 'LKSBAWQ_DO_pct', 'LKSBAWQ_F_DO_pct',
#        'LKSBAWQ_DO_mgl', 'LKSBAWQ_F_DO_mgl', 'LKSBAWQ_Depth',
#        'LKSBAWQ_F_Depth', 'LKSBAWQ_cDepth', 'LKSBAWQ_F_cDepth', 'LKSBAWQ_pH',
#        'LKSBAWQ_F_pH', 'LKSBAWQ_Turb', 'LKSBAWQ_F_Turb', 'LKSBAWQ_ChlFluor',
# ...

# %%
#Exclude data that was flagged (0=Passed Initial QAQC Checks, -2=Missing Data, 5=Corrected Data)
data_quality_codes = ['<0>', '<0> [GMT]','<-2>','<-2> [GMT]','<-2> [GMC]', '<-2> [GPD](CSM)','<5>']
filtered_wqtemp_df = merged_df[merged_df['LKSPOMET_F_ATemp'].isin(data_quality_codes)]
filtered_wqtemp_df.head()
# Out:
#          DateTimeStamp LKSPOMET_Station_Code LKSPOMET_isSWMP  \
# 7532  03/20/2018 10:45              LKSPOMET               P
# 7533  03/20/2018 11:00              LKSPOMET               P
# 7534  03/20/2018 11:15              LKSPOMET               P
# 7535  03/20/2018 11:30              LKSPOMET               P
# 7536  03/20/2018 11:45              LKSPOMET               P
#
#      LKSPOMET_F_Record  LKSPOMET_ATemp LKSPOMET_F_ATemp  LKSPOMET_RH  \
# 7532             {CSM}             NaN       <-2> [GMT]          NaN
# 7533             {CSM}             NaN       <-2> [GMT]          NaN
# 7534             {CSM}             NaN       <-2> [GMT]          NaN
# 7535             {CSM}             NaN       <-2> [GMT]          NaN
# 7536             {CSM}             NaN       <-2> [GMT]          NaN
#
#      LKSPOMET_F_RH  LKSPOMET_BP LKSPOMET_F_BP  ...  LKSBANUT_F_NH4F  \
# 7532    <-2> [GMT]          NaN    <-2> [GMT]  ...              NaN
# ...

# %%
refined_df = merged_df[(['DateTimeStamp', 'LKSPOMET_Station_Code', 'LKSPOMET_isSWMP',
       'LKSPOMET_F_Record', 'LKSPOMET_ATemp', 'LKSPOMET_F_ATemp',
       'LKSPOMET_RH', 'LKSPOMET_F_RH', 'LKSPOMET_BP', 'LKSPOMET_F_BP',
       'LKSPOMET_WSpd', 'LKSPOMET_F_WSpd', 'LKSPOMET_MaxWSpd', 'LKSPOMET_Wdir',
       'LKSPOMET_F_Wdir', 'LKSPOMET_SDWDir', 'LKSPOMET_F_SDWDir',
       'LKSPOMET_TotPAR', 'LKSPOMET_F_TotPAR', 'LKSPOMET_TotPrcp',
       'LKSPOMET_F_TotPrcp', 'LKSPOMET_TotSoRad', 'LKSPOMET_F_TotSoRad',
       'LKSBAWQ_Station_Code', 'LKSBAWQ_isSWMP', 'LKSBAWQ_F_Record',
       'LKSBAWQ_Temp', 'LKSBAWQ_F_Temp', 'LKSBAWQ_SpCond', 'LKSBAWQ_F_SpCond',
       'LKSBAWQ_Sal', 'LKSBAWQ_F_Sal', 'LKSBAWQ_DO_pct', 'LKSBAWQ_F_DO_pct',
       'LKSBAWQ_DO_mgl', 'LKSBAWQ_F_DO_mgl', 'LKSBAWQ_Depth',
       'LKSBAWQ_F_Depth', 'LKSBAWQ_cDepth', 'LKSBAWQ_F_cDepth', 'LKSBAWQ_pH',
       'LKSBAWQ_F_pH', 'LKSBAWQ_Turb', 'LKSBAWQ_F_Turb', 'LKSBAWQ_ChlFluor',
       'LKSBAWQ_F_ChlFluor', 'LKSBANUT_Station_Code', 'LKSBANUT_isSWMP',
       'LKSBANUT_DateTimeStamp', 'LKSBANUT_CollMethd', 'LKSBANUT_REP',
       'LKSBANUT_F_Record', 'LKSBANUT_PO4F', 'LKSBANUT_F_PO4F',
       'LKSBANUT_NH4F', 'LKSBANUT_F_NH4F', 'LKSBANUT_NO2F', 'LKSBANUT_F_NO2F',
       'LKSBANUT_NO3F', 'LKSBANUT_F_NO3F', 'LKSBANUT_NO23F',
       'LKSBANUT_F_NO23F', 'LKSBANUT_CHLA_N', 'LKSBANUT_F_CHLA_N',
       'Unnamed: 64'],
      dtype='object')

# %%
# Out:
#      DateTimeStamp Station_Code SWMP_Indicator Flag_Column  Average_Temp  \
# 0  01/01/2018 0:00     LKSPOMET              P       {CSM}         -24.5
# 1  01/01/2018 0:15     LKSPOMET              P       {CSM}         -24.7
# 2  01/01/2018 0:30     LKSPOMET              P       {CSM}         -24.8
# 3  01/01/2018 0:45     LKSPOMET              P       {CSM}         -25.0
# 4  01/01/2018 1:00     LKSPOMET              P       {CSM}         -25.2
#
#   Temp_Metadata_Notes  Average_Relative_Humiditiy Humidity_Metadata_Notes  \
# 0                <0>                         67.0                    <0>
# 1                <0>                         67.0                    <0>
# 2                <0>                         67.0                    <0>
# 3                <0>                         67.0                    <0>
# 4                <0>                         67.0                    <0>
#
#    Average_Barometric_Pressure Pressure_Metadata_Notes  ...  LKSPONUT_F_NH4F  \
# ...

# %%
# Extract "name", "goal", "pledged", "outcome", "country", "staff_pick",
# "backers_count", and "spotlight"
##reduced_ps_df = df.loc[:, ["", "goal", "pledged",
                                    "outcome", "country", "staff_pick", "backers_count", "spotlight"]]
#reduced_crowdfunding_df
# Out:
#                              name    goal  pledged     outcome country  \
# 0      Baldwin, Riley and Jackson     100        0      failed      CA
# 1                        Odom Inc    1400    14560  successful      US
# 2      Melton, Robinson and Fritz  108400   142523  successful      AU
# 3     Mcdonald, Gonzalez and Ross    4200     2477      failed      US
# 4                   Larson-Little    7600     5265      failed      US
# ..                            ...     ...      ...         ...     ...
# 995              Manning-Hamilton   97300   153216  successful      US
# 996                    Butler LLC    6600     4814      failed      US
# 997                      Ball LLC    7600     4603    canceled      IT
# 998   Taylor, Santiago and Flores   66600    37823      failed      US
# 999  Hernandez, Norton and Kelley  111100    62819    canceled      US
#
#      staff_pick  backers_count  spotlight
# 0         False              0      False
# ...

# %%
# Remove projects that made no money at all
reduced_crowdfunding_df = reduced_crowdfunding_df.loc[(
    reduced_crowdfunding_df["pledged"] > 0)]
reduced_crowdfunding_df.head()
# Out:
#                           name    goal  pledged     outcome country  \
# 1                     Odom Inc    1400    14560  successful      US
# 2   Melton, Robinson and Fritz  108400   142523  successful      AU
# 3  Mcdonald, Gonzalez and Ross    4200     2477      failed      US
# 4                Larson-Little    7600     5265      failed      US
# 5                 Harris Group    7600    13195  successful      DK
#
#    staff_pick  backers_count  spotlight
# 1       False            158       True
# 2       False           1425      False
# 3       False             24      False
# 4       False             53      False
# 5       False            174      False

# %%
# Collect only those projects that were hosted in the US.

# Create a list of the columns
columns = [
    "name", "goal", "pledged", "outcome", 
    "country", "staff_pick", "backers_count", "spotlight"]

#  Create a new df for "US" with the columns. 
hosted_in_us_df = reduced_crowdfunding_df.loc[reduced_crowdfunding_df["country"] == "US",  columns]
hosted_in_us_df.head()
# Out:
#                            name  goal  pledged     outcome country  \
# 1                      Odom Inc  1400    14560  successful      US
# 3   Mcdonald, Gonzalez and Ross  4200     2477      failed      US
# 4                 Larson-Little  7600     5265      failed      US
# 9        Rangel, Holt and Jones  6200     3208      failed      US
# 10                    Green Ltd  5200    13838  successful      US
#
#     staff_pick  backers_count  spotlight
# 1        False            158       True
# 3        False             24      False
# 4        False             53      False
# 9        False             44      False
# 10       False            220      False

# %%
# Create a new column that finds the average amount pledged to a project
average_donation = hosted_in_us_df['pledged'] / hosted_in_us_df['backers_count']
average_donation
# Out:
# 1       92.151899
# 3      103.208333
# 4       99.339623
# 9       72.909091
# 10      62.900000
#           ...
# 994     87.972684
# 995     74.995595
# 996     42.982143
# 998    101.131016
# 999     55.988414
# Length: 762, dtype: float64

# %%
# Create a new column that finds the average amount pledged to a project
hosted_in_us_df["average_donation"] = hosted_in_us_df['pledged'] / \
    hosted_in_us_df['backers_count']

# %%
# First convert "average_donation", "goal", and "pledged" columns to float
# Then Format to go to two decimal places, include a dollar sign, and use comma notation

hosted_in_us_df["average_donation"] = hosted_in_us_df["average_donation"].astype(float).map(
    "${:,.2f}".format)
hosted_in_us_df["goal"] = hosted_in_us_df["goal"].astype(float).map("${:,.2f}".format)
hosted_in_us_df["pledged"] = hosted_in_us_df["pledged"].astype(float).map("${:,.2f}".format)

# %%
hosted_in_us_df.head()
# Out:
#                            name       goal     pledged     outcome country  \
# 1                      Odom Inc  $1,400.00  $14,560.00  successful      US
# 3   Mcdonald, Gonzalez and Ross  $4,200.00   $2,477.00      failed      US
# 4                 Larson-Little  $7,600.00   $5,265.00      failed      US
# 9        Rangel, Holt and Jones  $6,200.00   $3,208.00      failed      US
# 10                    Green Ltd  $5,200.00  $13,838.00  successful      US
#
#     staff_pick  backers_count  spotlight average_donation
# 1        False            158       True           $92.15
# 3        False             24      False          $103.21
# 4        False             53      False           $99.34
# 9        False             44      False           $72.91
# 10       False            220      False           $62.90

# %%
# Calculate the total number of backers for all US projects
hosted_in_us_df["backers_count"].sum()
# Out:
# 545510

# %%
# Calculate the average number of backers for all US projects
hosted_in_us_df["backers_count"].mean()
# Out:
# 715.8923884514436

# %%
# Collect only those US campaigns that have been picked as a "Staff Pick"
picked_by_staff_df = hosted_in_us_df.loc[hosted_in_us_df["staff_pick"] == True]
picked_by_staff_df
# Out:
#                               name         goal      pledged     outcome  \
# 76       Martin, Conway and Larsen  $122,900.00   $95,993.00      failed
# 86                     Davis-Smith    $7,400.00   $12,405.00  successful
# 193       Calhoun, Rogers and Long    $6,600.00    $3,012.00      failed
# 205                 Weaver-Marquez    $1,300.00    $5,614.00  successful
# 220                       Owens-Le    $7,900.00      $667.00      failed
# 221                       Huff LLC  $121,500.00  $119,830.00      failed
# 225                      Fox-Quinn   $67,800.00  $176,398.00  successful
# 259                    Watkins Ltd    $1,800.00   $10,755.00  successful
# 291          Bell, Grimes and Kerr    $1,800.00    $8,219.00  successful
# 384       Baker, Collins and Smith  $114,400.00  $196,779.00  successful
# 395                     Taylor PLC    $7,100.00    $9,238.00  successful
# 406                      Lyons Inc   $39,300.00   $71,583.00  successful
# ...

# %%
# Group by the outcome of the campaigns and see if staff picks matter (Seems to matter quite a bit)
outcome_groups = picked_by_staff_df.groupby("outcome")
outcome_groups["name"].count()
# Out:
# outcome
# canceled       3
# failed        13
# successful    23
# Name: name, dtype: int64
